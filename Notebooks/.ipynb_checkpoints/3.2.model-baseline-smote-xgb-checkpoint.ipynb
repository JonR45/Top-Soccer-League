# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support
from imblearn.over_sampling import SMOTE
from collections import Counter

# import stored variables from previous notebook
# %store -r model_metrics_dict

# %% [markdown]
# # Load data

# %%
raw_data = pd.read_csv('../Data/Final/players_outfield_prepared.csv')
data = raw_data.copy()
df = pd.DataFrame(data)
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Age  Height  Weight  Overall  Potential  Growth  TotalStats  BaseStats  \
# 0   35     169      67       91         91       0        2190        452
# 1   34     185      81       91         91       0        2147        455
# 2   33     185      81       91         91       0        2205        458
# 3   31     181      70       91         91       0        2303        483
# 4   23     182      73       91         95       4        2177        470
#
#    BestPosition  IntReputation  WeakFoot  SkillMoves  AttackingWorkRate  \
# 0             0              5         4           4                  1
# 1             3              4         4           4                  2
# 2            13              5         4           4                  0
# 3             4              4         5           4                  0
# 4            13              4         4           5                  0
#
#    DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0                  1         81             89            90              94
# 1                  2         80             88            83              87
# 2                  2         75             91            79              86
# 3                  0         74             88            93              87
# 4                  1         97             89            80              92
#
#    DefendingTotal  PhysicalityTotal  Crossing  Finishing  HeadingAccuracy  \
# 0              34                64        84         90               70
# 1              39                78        75         92               90
# 2              44                83        71         94               91
# 3              64                77        94         85               55
# 4              36                76        78         93               72
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0            91       88         95     93          93           90
# 1            89       88         87     82          73           76
# 2            84       89         85     79          85           70
# 3            93       83         88     89          83           93
# 4            85       83         93     80          69           71
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0           93            87           76       91         92       95
# 1           91            79           80       78         92       72
# 2           89            76           75       77         93       82
# 3           90            76           73       76         91       78
# 4           91            97           97       93         93       81
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0         86       68       70        68         91          44
# 1         87       79       82        82         80          63
# 2         91       85       76        87         84          81
# 3         92       63       88        74         91          75
# 4         88       77       87        76         82          64
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0             40           93      94         75         96       20
# 1             39           92      89         84         90       43
# 2             49           94      81         90         88       35
# 3             66           88      94         83         89       68
# 4             38           92      83         80         88       26
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              35             24         6          11         15
# 1              24             18        13          11          5
# 2              42             19        15           6         12
# 3              65             53        15          13          5
# 4              34             32        13           5          7
#
#    GKPositioning  GKReflexes  STRating  LWRating  LFRating  CFRating  \
# 0             14           8        90        90        91        91
# 1              5           7        91        87        89        89
# 2              8          10        91        85        88        88
# 3             10          13        86        88        87        87
# 4             11           6        92        90        90        90
#
#    RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  LWBRating  \
# 0        91        90         91        91        88        91         67
# 1        89        87         91        89        84        89         67
# 2        88        85         88        86        83        86         67
# 3        87        88         91        91        91        91         82
# 4        90        90         92        92        84        92         70
#
#    CDMRating  RWBRating  LBRating  CBRating  RBRating  GKRating  Top_5_league
# 0         66         67        62        53        62        22             1
# 1         67         67        63        58        63        21             1
# 2         69         67        64        63        64        22             1
# 3         82         82        78        72        78        24             1
# 4         66         70        66        57        66        21             1

# %%
# check shape
df.shape
# Out:
# (16478, 72)

# %%
# check balance of dataset
df['Top_5_league'].value_counts()
# Out:
# 0    13908
# 1     2570
# Name: Top_5_league, dtype: int64

# %% [markdown]
# # Remove features
# - Only features that were determined to be useful (by way of having significant differences in mean and median values) will be included

# %%
df = df[['Overall', 'Potential', 'SkillMoves', 'PaceTotal', 'ShootingTotal',
       'PassingTotal', 'DribblingTotal', 'DefendingTotal', 'PhysicalityTotal',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Agility', 'Reactions',
       'ShotPower', 'LongShots','Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'STRating',
       'LWRating', 'LFRating', 'CFRating', 'RFRating', 'RWRating', 'CAMRating',
       'LMRating', 'CMRating', 'RMRating', 'LWBRating', 'CDMRating',
       'RWBRating', 'LBRating', 'CBRating', 'RBRating','Top_5_league']]

df.head()
# Out:
#    Overall  Potential  SkillMoves  PaceTotal  ShootingTotal  PassingTotal  \
# 0       91         91           4         81             89            90
# 1       91         91           4         80             88            83
# 2       91         91           4         75             91            79
# 3       91         91           4         74             88            93
# 4       91         95           5         97             89            80
#
#    DribblingTotal  DefendingTotal  PhysicalityTotal  Crossing  Finishing  \
# 0              94              34                64        84         90
# 1              87              39                78        75         92
# 2              86              44                83        71         94
# 3              87              64                77        94         85
# 4              92              36                76        78         93
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0               70            91       88         95     93          93
# 1               90            89       88         87     82          73
# 2               91            84       89         85     79          85
# 3               55            93       83         88     89          83
# 4               72            85       83         93     80          69
#
#    LongPassing  BallControl  Agility  Reactions  ShotPower  LongShots  \
# 0           90           93       91         92         86         91
# 1           76           91       78         92         87         80
# 2           70           89       77         93         91         84
# 3           93           90       76         91         92         91
# 4           71           91       93         93         88         82
#
#    Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0          44             40           93      94         75         96
# 1          63             39           92      89         84         90
# 2          81             49           94      81         90         88
# 3          75             66           88      94         83         89
# 4          64             38           92      83         80         88
#
#    Marking  StandingTackle  SlidingTackle  STRating  LWRating  LFRating  \
# 0       20              35             24        90        90        91
# 1       43              24             18        91        87        89
# 2       35              42             19        91        85        88
# 3       68              65             53        86        88        87
# 4       26              34             32        92        90        90
#
#    CFRating  RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  \
# 0        91        91        90         91        91        88        91
# 1        89        89        87         91        89        84        89
# 2        88        88        85         88        86        83        86
# 3        87        87        88         91        91        91        91
# 4        90        90        90         92        92        84        92
#
#    LWBRating  CDMRating  RWBRating  LBRating  CBRating  RBRating  Top_5_league
# 0         67         66         67        62        53        62             1
# 1         67         67         67        63        58        63             1
# 2         67         69         67        64        63        64             1
# 3         82         82         82        78        72        78             1
# 4         70         66         70        66        57        66             1

# %% [markdown]
# # Train test split

# %%
X = df.drop(['Top_5_league'], axis=1)
y = df['Top_5_league']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)

# %% [markdown]
# # Balance the dataset: SMOTE

# %%
# instantiate
sm = SMOTE(random_state=42)
# use smote to create more samples
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %% [markdown]
# ### Visualise balance of dataset

# %%
# get a count of the classes in the dataset
counter = Counter(y)

# visualise balance of entire dataset
for k,v in counter.items():
    percentage_of_total = v / len(y) * 100
    print(f"Class={k}, n={v} ({round(percentage_of_total, 2)}%)")

# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.title("Balance of the entire dataset")
plt.ylabel("Volume")
plt.xticks(ticks=np.arange(0, 2, step=1), labels=[0,1])
plt.show()
# Out:
# Class=1, n=2570 (15.6%)
# Class=0, n=13908 (84.4%)

# %%
# get a count of the classes in the training dataset
counter = Counter(y_train)

# visualise balance of the training dataset

for k,v in counter.items():
    percentage_of_total = v / len(y_train) * 100
    print(f"Class={k}, n={v} ({round(percentage_of_total, 2)}%)")

# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.title("Balance of the training dataset")
plt.ylabel("Volume")
plt.xticks(ticks=np.arange(0, 2, step=1), labels=[0,1])

plt.show()
# Out:
# Class=0, n=11126 (84.4%)
# Class=1, n=2056 (15.6%)

# %%
# get a count of the classes in the smoted training dataset
counter = Counter(y_train_smote)

# visualise balance of the smoted training dataset
for k,v in counter.items():
    percentage_of_total = v / len(y_train_smote) * 100
    print(f"Class={k}, n={v} ({round(percentage_of_total, 2)}%)")

# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.title("Balance of the 'smoted' training dataset")
plt.ylabel("Volume")
plt.xticks(ticks=np.arange(0, 2, step=1), labels=[0,1])

plt.show()
# Out:
# Class=0, n=11126 (50.0%)
# Class=1, n=11126 (50.0%)

# %% [markdown]
# # Fit model

# %%
# instantiate
xgb_model = xgb.XGBClassifier(random_state=42)

# fit model
xgb_model.fit(X_train_smote, y_train_smote)

# make predictions on test set
xgb_predictions = xgb_model.predict(X_test)

# %% [markdown]
# # Evaluate Model

# %%
# Calculate and print the accuracy of the model
accuracy = accuracy_score(y_true=y_test, y_pred=xgb_predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8668082524271845

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_true=y_test, y_pred=xgb_predictions, labels=xgb_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgb_model.classes_)
disp.plot()
plt.title("Confusion Matrix: XGB")
plt.show()

# %%
print(classification_report(y_true=y_test, y_pred=xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2782
#            1       0.56      0.70      0.62       514
#
#     accuracy                           0.87      3296
#    macro avg       0.75      0.80      0.77      3296
# weighted avg       0.88      0.87      0.87      3296

# %% [markdown]
# # Compare models

# %%
# create a dataframe to allow quick comparison of models (add more models to the dictionary as they are created)
metrics = precision_recall_fscore_support(y_true=y_test, y_pred=xgb_predictions)

# Extract precision, recall, f1-score, and support and round to two decimal places
precision = [round(p, 2) for p in metrics[0]]
recall = [round(r, 2) for r in metrics[1]]
f1_score = [round(f, 2) for f in metrics[2]]
support = metrics[3]

# update dictionary to include new model
model_metrics_dict['XGB_Baseline_SMOTE'] = {
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1_score,
        "Accuracy": round(accuracy, 2),
        "Support": support,
}

# %%
# create dataframe from model metrics dictionary - values will be displayed as a list of negative and positive class data
df_report = pd.DataFrame(data=model_metrics_dict)
# rename the index column to 'metric'
df_report.index.rename('Metric', inplace=True)
# reset the index so there is a standard numerical index
df_report.reset_index(inplace=True)
# check output
df_report
# Out:
#       Metric  XGB_Baseline XGB_Tuned_Random_Search XGB_Baseline_SMOTE
# 0  Precision  [0.92, 0.73]            [0.96, 0.46]       [0.94, 0.56]
# 1     Recall  [0.96, 0.56]            [0.82, 0.82]         [0.9, 0.7]
# 2   F1 Score  [0.94, 0.64]            [0.89, 0.59]       [0.92, 0.62]
# 3   Accuracy           0.9                    0.82               0.87
# 4    Support   [2782, 514]             [2782, 514]        [2782, 514]

# %% [markdown]
# ## Store variables

# %%
# %store model_metrics_dict
# Out:
# Stored 'model_metrics_dict' (dict)
