# %% [markdown]
# # Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import shap

# %% [markdown]
# # Load data

# %%
raw_data = pd.read_csv('../Data/Final/players_prepared.csv')
data = raw_data.copy()
df = pd.DataFrame(data)
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Age  Height  Weight  Overall  Potential  Growth  TotalStats  BaseStats  \
# 0   35     169      67       91         91       0        2190        452
# 1   34     185      81       91         91       0        2147        455
# 2   33     185      81       91         91       0        2205        458
# 3   31     181      70       91         91       0        2303        483
# 4   23     182      73       91         95       4        2177        470
#
#    BestPosition   ValueEUR  WageEUR  ReleaseClause  IntReputation  WeakFoot  \
# 0             0   54000000   195000       99900000              5         4
# 1             3   64000000   450000      131199999              4         4
# 2            14   84000000   420000      172200000              5         4
# 3             4  107500000   350000      198900000              4         5
# 4            14  190500000   230000      366700000              4         4
#
#    SkillMoves  AttackingWorkRate  DefensiveWorkRate  PaceTotal  ShootingTotal  \
# 0           4                  1                  1         81             89
# 1           4                  2                  2         80             88
# 2           4                  0                  2         75             91
# 3           4                  0                  0         74             88
# 4           5                  0                  1         97             89
#
#    PassingTotal  DribblingTotal  DefendingTotal  PhysicalityTotal  Crossing  \
# 0            90              94              34                64        84
# 1            83              87              39                78        75
# 2            79              86              44                83        71
# 3            93              87              64                77        94
# 4            80              92              36                76        78
#
#    Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# 0         90               70            91       88         95     93
# 1         92               90            89       88         87     82
# 2         94               91            84       89         85     79
# 3         85               55            93       83         88     89
# 4         93               72            85       83         93     80
#
#    FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  \
# 0          93           90           93            87           76       91
# 1          73           76           91            79           80       78
# 2          85           70           89            76           75       77
# 3          83           93           90            76           73       76
# 4          69           71           91            97           97       93
#
#    Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# 0         92       95         86       68       70        68         91
# 1         92       72         87       79       82        82         80
# 2         93       82         91       85       76        87         84
# 3         91       78         92       63       88        74         91
# 4         93       81         88       77       87        76         82
#
#    Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0          44             40           93      94         75         96
# 1          63             39           92      89         84         90
# 2          81             49           94      81         90         88
# 3          75             66           88      94         83         89
# 4          64             38           92      83         80         88
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0       20              35             24         6          11         15
# 1       43              24             18        13          11          5
# 2       35              42             19        15           6         12
# 3       68              65             53        15          13          5
# 4       26              34             32        13           5          7
#
#    GKPositioning  GKReflexes  STRating  LWRating  LFRating  CFRating  \
# 0             14           8        90        90        91        91
# 1              5           7        91        87        89        89
# 2              8          10        91        85        88        88
# 3             10          13        86        88        87        87
# 4             11           6        92        90        90        90
#
#    RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  LWBRating  \
# 0        91        90         91        91        88        91         67
# 1        89        87         91        89        84        89         67
# 2        88        85         88        86        83        86         67
# 3        87        88         91        91        91        91         82
# 4        90        90         92        92        84        92         70
#
#    CDMRating  RWBRating  LBRating  CBRating  RBRating  GKRating  Top_5_league
# 0         66         67        62        53        62        22             1
# 1         67         67        63        58        63        21             1
# 2         69         67        64        63        64        22             1
# 3         82         82        78        72        78        24             1
# 4         66         70        66        57        66        21             1

# %% [markdown]
# ## Check shape and target value balance

# %%
df.shape
# Out:
# (18539, 75)

# %%
df['Top_5_league'].value_counts()
# Out:
# 0    15634
# 1     2905
# Name: Top_5_league, dtype: int64

# %% [markdown]
# The 1s in our target variable (representing the players that play in the top 5 leagues) make up a small portion of the dataset. Let's see how the model performs, if it performs poorly then balancing the dataset is something to be considered.

# %% [markdown]
# # Drop monetary features

# %%
# drop monetary value features
cols_to_drop = ['ValueEUR', 'WageEUR', 'ReleaseClause',]
df = df.drop(cols_to_drop, axis=1)
df.head()
# Out:
#    Age  Height  Weight  Overall  Potential  Growth  TotalStats  BaseStats  \
# 0   35     169      67       91         91       0        2190        452
# 1   34     185      81       91         91       0        2147        455
# 2   33     185      81       91         91       0        2205        458
# 3   31     181      70       91         91       0        2303        483
# 4   23     182      73       91         95       4        2177        470
#
#    BestPosition  IntReputation  WeakFoot  SkillMoves  AttackingWorkRate  \
# 0             0              5         4           4                  1
# 1             3              4         4           4                  2
# 2            14              5         4           4                  0
# 3             4              4         5           4                  0
# 4            14              4         4           5                  0
#
#    DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0                  1         81             89            90              94
# 1                  2         80             88            83              87
# 2                  2         75             91            79              86
# 3                  0         74             88            93              87
# 4                  1         97             89            80              92
#
#    DefendingTotal  PhysicalityTotal  Crossing  Finishing  HeadingAccuracy  \
# 0              34                64        84         90               70
# 1              39                78        75         92               90
# 2              44                83        71         94               91
# 3              64                77        94         85               55
# 4              36                76        78         93               72
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0            91       88         95     93          93           90
# 1            89       88         87     82          73           76
# 2            84       89         85     79          85           70
# 3            93       83         88     89          83           93
# 4            85       83         93     80          69           71
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0           93            87           76       91         92       95
# 1           91            79           80       78         92       72
# 2           89            76           75       77         93       82
# 3           90            76           73       76         91       78
# 4           91            97           97       93         93       81
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0         86       68       70        68         91          44
# 1         87       79       82        82         80          63
# 2         91       85       76        87         84          81
# 3         92       63       88        74         91          75
# 4         88       77       87        76         82          64
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0             40           93      94         75         96       20
# 1             39           92      89         84         90       43
# 2             49           94      81         90         88       35
# 3             66           88      94         83         89       68
# 4             38           92      83         80         88       26
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              35             24         6          11         15
# 1              24             18        13          11          5
# 2              42             19        15           6         12
# 3              65             53        15          13          5
# 4              34             32        13           5          7
#
#    GKPositioning  GKReflexes  STRating  LWRating  LFRating  CFRating  \
# 0             14           8        90        90        91        91
# 1              5           7        91        87        89        89
# 2              8          10        91        85        88        88
# 3             10          13        86        88        87        87
# 4             11           6        92        90        90        90
#
#    RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  LWBRating  \
# 0        91        90         91        91        88        91         67
# 1        89        87         91        89        84        89         67
# 2        88        85         88        86        83        86         67
# 3        87        88         91        91        91        91         82
# 4        90        90         92        92        84        92         70
#
#    CDMRating  RWBRating  LBRating  CBRating  RBRating  GKRating  Top_5_league
# 0         66         67        62        53        62        22             1
# 1         67         67        63        58        63        21             1
# 2         69         67        64        63        64        22             1
# 3         82         82        78        72        78        24             1
# 4         66         70        66        57        66        21             1

# %% [markdown]
# # Split data

# %%
X = df.drop(['Top_5_league'], axis=1)
y = df['Top_5_league']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)

# %% [markdown]
# # Fit XGBClassifier model

# %%
# instantiate
xgb_model = xgb.XGBClassifier(random_state=42)

# fit model
xgb_model.fit(X_train, y_train)

# make predictions on the test data
xgb_predictions = xgb_model.predict(X_test)

# %% [markdown]
# # Evaluate model

# %%
accuracy_score(y_true=y_test, y_pred=xgb_predictions)
# Out:
# 0.8980582524271845

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_test, xgb_predictions, labels=xgb_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgb_model.classes_)
disp.plot()
plt.title("Confusion Matrix: XGB")
plt.show()

# %%
print(classification_report(y_true=y_test, y_pred=xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3127
#            1       0.73      0.55      0.63       581
#
#     accuracy                           0.90      3708
#    macro avg       0.83      0.76      0.78      3708
# weighted avg       0.89      0.90      0.89      3708

# %% [markdown]
# # Shapley values
# I want to explore the feature importance and so will use Shapley values for this.

# %%
shap_values = shap.TreeExplainer(xgb_model).shap_values(X_train)
shap.summary_plot(shap_values, X_train, plot_type="bar", max_display=1000)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# # Next Steps
# - The Shapley feature importance shows that there are lots of features that have similar amounts of very small influence and only a few that have a significant impact.
# - Using domain knowledge, think about what would influence whether a player is playing at the highest level in Europe, and use thes features only.
# - Keep only the features you believe will be useful and run the model again.
