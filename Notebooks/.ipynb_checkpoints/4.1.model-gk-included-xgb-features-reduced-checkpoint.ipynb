# %% [markdown]
# # XGB All Players Model
# ## Reduced features

# %% [markdown]
# # Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import shap

# %% [markdown]
# # Load data

# %%
raw_data = pd.read_csv('../Data/Final/players_prepared.csv')
data = raw_data.copy()
df = pd.DataFrame(data)
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Age  Height  Weight  Overall  Potential  Growth  TotalStats  BaseStats  \
# 0   35     169      67       91         91       0        2190        452
# 1   34     185      81       91         91       0        2147        455
# 2   33     185      81       91         91       0        2205        458
# 3   31     181      70       91         91       0        2303        483
# 4   23     182      73       91         95       4        2177        470
#
#    BestPosition   ValueEUR  WageEUR  ReleaseClause  IntReputation  WeakFoot  \
# 0             0   54000000   195000       99900000              5         4
# 1             3   64000000   450000      131199999              4         4
# 2            14   84000000   420000      172200000              5         4
# 3             4  107500000   350000      198900000              4         5
# 4            14  190500000   230000      366700000              4         4
#
#    SkillMoves  AttackingWorkRate  DefensiveWorkRate  PaceTotal  ShootingTotal  \
# 0           4                  1                  1         81             89
# 1           4                  2                  2         80             88
# 2           4                  0                  2         75             91
# 3           4                  0                  0         74             88
# 4           5                  0                  1         97             89
#
#    PassingTotal  DribblingTotal  DefendingTotal  PhysicalityTotal  Crossing  \
# 0            90              94              34                64        84
# 1            83              87              39                78        75
# 2            79              86              44                83        71
# 3            93              87              64                77        94
# 4            80              92              36                76        78
#
#    Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# 0         90               70            91       88         95     93
# 1         92               90            89       88         87     82
# 2         94               91            84       89         85     79
# 3         85               55            93       83         88     89
# 4         93               72            85       83         93     80
#
#    FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  \
# 0          93           90           93            87           76       91
# 1          73           76           91            79           80       78
# 2          85           70           89            76           75       77
# 3          83           93           90            76           73       76
# 4          69           71           91            97           97       93
#
#    Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# 0         92       95         86       68       70        68         91
# 1         92       72         87       79       82        82         80
# 2         93       82         91       85       76        87         84
# 3         91       78         92       63       88        74         91
# 4         93       81         88       77       87        76         82
#
#    Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0          44             40           93      94         75         96
# 1          63             39           92      89         84         90
# 2          81             49           94      81         90         88
# 3          75             66           88      94         83         89
# 4          64             38           92      83         80         88
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0       20              35             24         6          11         15
# 1       43              24             18        13          11          5
# 2       35              42             19        15           6         12
# 3       68              65             53        15          13          5
# 4       26              34             32        13           5          7
#
#    GKPositioning  GKReflexes  STRating  LWRating  LFRating  CFRating  \
# 0             14           8        90        90        91        91
# 1              5           7        91        87        89        89
# 2              8          10        91        85        88        88
# 3             10          13        86        88        87        87
# 4             11           6        92        90        90        90
#
#    RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  LWBRating  \
# 0        91        90         91        91        88        91         67
# 1        89        87         91        89        84        89         67
# 2        88        85         88        86        83        86         67
# 3        87        88         91        91        91        91         82
# 4        90        90         92        92        84        92         70
#
#    CDMRating  RWBRating  LBRating  CBRating  RBRating  GKRating  Top_5_league
# 0         66         67        62        53        62        22             1
# 1         67         67        63        58        63        21             1
# 2         69         67        64        63        64        22             1
# 3         82         82        78        72        78        24             1
# 4         66         70        66        57        66        21             1

# %% [markdown]
# ## Check shape and target value balance

# %%
df.shape
# Out:
# (18539, 75)

# %%
df['Top_5_league'].value_counts()
# Out:
# 0    15634
# 1     2905
# Name: Top_5_league, dtype: int64

# %% [markdown]
# The 1s in our target variable (representing the players that play in the top 5 leagues) make up a small portion of the dataset. Let's see how the model performs, if it performs poorly then balancing the dataset is something to be considered.

# %% [markdown]
# # Remove features

# %% [markdown]
# Include only the features that the Shapley values indicated were impactful.

# %%
df =df[['Overall', 'Potential', 'SkillMoves', 'PaceTotal', 'ShootingTotal',
       'PassingTotal', 'DribblingTotal', 'DefendingTotal', 'PhysicalityTotal',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Agility', 'Reactions',
       'ShotPower', 'LongShots','Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'STRating','LWRating', 'LFRating', 'CAMRating',
       'LMRating', 'CMRating', 'LWBRating', 'CDMRating', 'LBRating', 'CBRating', 'Top_5_league']]

df.head()
# Out:
#    Overall  Potential  SkillMoves  PaceTotal  ShootingTotal  PassingTotal  \
# 0       91         91           4         81             89            90
# 1       91         91           4         80             88            83
# 2       91         91           4         75             91            79
# 3       91         91           4         74             88            93
# 4       91         95           5         97             89            80
#
#    DribblingTotal  DefendingTotal  PhysicalityTotal  Crossing  Finishing  \
# 0              94              34                64        84         90
# 1              87              39                78        75         92
# 2              86              44                83        71         94
# 3              87              64                77        94         85
# 4              92              36                76        78         93
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0               70            91       88         95     93          93
# 1               90            89       88         87     82          73
# 2               91            84       89         85     79          85
# 3               55            93       83         88     89          83
# 4               72            85       83         93     80          69
#
#    LongPassing  BallControl  Agility  Reactions  ShotPower  LongShots  \
# 0           90           93       91         92         86         91
# 1           76           91       78         92         87         80
# 2           70           89       77         93         91         84
# 3           93           90       76         91         92         91
# 4           71           91       93         93         88         82
#
#    Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0          44             40           93      94         75         96
# 1          63             39           92      89         84         90
# 2          81             49           94      81         90         88
# 3          75             66           88      94         83         89
# 4          64             38           92      83         80         88
#
#    Marking  StandingTackle  SlidingTackle  STRating  LWRating  LFRating  \
# 0       20              35             24        90        90        91
# 1       43              24             18        91        87        89
# 2       35              42             19        91        85        88
# 3       68              65             53        86        88        87
# 4       26              34             32        92        90        90
#
#    CAMRating  LMRating  CMRating  LWBRating  CDMRating  LBRating  CBRating  \
# 0         91        91        88         67         66        62        53
# 1         91        89        84         67         67        63        58
# 2         88        86        83         67         69        64        63
# 3         91        91        91         82         82        78        72
# 4         92        92        84         70         66        66        57
#
#    Top_5_league
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# # Split data

# %%
X = df.drop(['Top_5_league'], axis=1)
y = df['Top_5_league']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)

# %% [markdown]
# # Fit XGBClassifier model

# %%
xgb_model = xgb.XGBClassifier(random_state=42)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
xgb_predictions = xgb_model.predict(X_test)

# %% [markdown]
# # Assess results

# %%
accuracy_score(y_true=y_test, y_pred=xgb_predictions)
# Out:
# 0.8972491909385113

# %% [markdown]
# - Reducing the features reduces accuracy to ~89.7%

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_test, xgb_predictions, labels=xgb_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgb_model.classes_)
disp.plot()
plt.title("Confusion Matrix: XGB")
plt.show()

# %% [markdown]
# ## Analyzing confusion matrix

# %%
print(classification_report(y_true=y_test, y_pred=xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      3127
#            1       0.75      0.52      0.61       581
#
#     accuracy                           0.90      3708
#    macro avg       0.83      0.74      0.78      3708
# weighted avg       0.89      0.90      0.89      3708

# %%
# Misclassification Rate:
1-accuracy_score(y_true=y_test, y_pred=xgb_predictions)
# Out:
# 0.1027508090614887

# %% [markdown]
# ### Reminder
#
# - **Accuracy** - The percentage of instances where the model's predictions were correct (TP + TN / TP + TN + FP + FN)
# - **Precision** - The percentage of positive predictions that were correct (TP / TP + FP). i.e., of all the times you predicted positive, what percentage of your predictions were correct?
# - **Recall** - The percentage of actual positive instances that were correctly predicted (TP / TP + FN). i.e., what % of the actual positive values were you able to correctly predict as positive.
# - **F1 score** - The harmonic mean of precision and recall (2 * precision * recall / precision + recall)
# - **Misclassification rate** - The percentage of instances where the model's predictions were incorrect (FP + FN / TP + TN + FP + FN)

# %% [markdown]
# ## Confusion Matrix Results
#
# - Precision for class 1 has reduced by ~3pp with the removal of ~50 features.
# - Recall for positive class reduced by 3pp from 55% to 52% so this tells us that the model will correctly predict only just over 1 out 2 actual positive values (52% accurate). This is not great.
# - Precision and Recall are still very high for class 0.

# %% [markdown]
# # Shapley values
# I want to explore the feature importance and so will use Shapley values for this.
#
# **What are Shapley values?** A prediction can be explained by assuming that each feature value of the instance is a “player” in a game where the prediction is the payout. Shapley values – a method from coalitional game theory – tells us how to fairly distribute the “payout” among the features.

# %%
shap_values = shap.TreeExplainer(xgb_model).shap_values(X_train)
shap.summary_plot(shap_values, X_train, plot_type="bar", max_display=1000)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# # Next Steps
# - Reducing the features has decreased the performance of the model but not drastically, so I'm going to stick with the reduced features.
# - I'm wondering if the model would be better split into goalkeeper and outfield players, so I'll run a new model with just the outfield player data.
# - After the above I can move on to balancing the dataset if necessary and hyperparameter tuning
